# %%
#libraries
from google.colab import drive
import os
import pandas as pd
from itertools import combinations, product
from pandas import set_option

# %%
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/Data Mining + DL/Data Mining/data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Accessing Data:

# %%
df = pd.read_csv('clean_data.csv')
df.head(5)
# Out:
#    Age  Gender         Country self_employed family_history treatment  \
# 0   37  Female   United States            No             No       Yes
# 1   44    Male   United States            No             No        No
# 2   32    Male          Canada            No             No        No
# 3   31    Male  United Kingdom            No            Yes       Yes
# 4   31    Male   United States            No             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely            6-25          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence
# 0                Yes              No
# 1         Don't know              No
# 2                 No              No
# 3                 No             Yes
# 4         Don't know              No
#
# [5 rows x 24 columns]

# %% [markdown]
# # Creating Rules:

# %%
def get_count(data, tuples):
    data = data.copy()
    data['Count'] = data.index
    ordered_categories = [category for (category, value) in tuples]
    counts = data.groupby(ordered_categories).count()['Count']
    count = counts
    for tup in tuples: 
      count = count[tup[1]]
    return count

# %%
def get_support(data, tuples):
    support = get_count(data,tuples)
    return support/len(data)

# %%
def get_confidence(data, predictors, outcomes):
    numerator = get_support(data,predictors+outcomes)
    denominator = get_support(data, predictors)
    return numerator / denominator

# %%
def get_lift(data,tuples):
    deno = 1 
    for tup in tuples: 
      deno *= get_support(data,[tup])
    return get_support(data,tuples) /deno

# %%
def get_category_value_tuples(data, categories):
    tuples = []
    for category in categories:
        for value in data[category].unique():
            tuples += [(category,value)]
    return tuples

# %%
response = ["treatment"]
predictor = [col for col in df if col not in response]
length = 2
min_sup = 0.03

# %%
outcomes = get_category_value_tuples(df, response)

rows = []
predictor_tuples = {}
for category in predictor: 
    predictor_tuples[category] = [unit for unit in get_category_value_tuples(df, [category]) if get_support(df,[unit]) > min_sup]

for predictor_combination in combinations(predictor,length):

    for relationship in product(*[predictor_tuples[category] for category in list(predictor_combination)], outcomes):

        predictor = list(relationship[0:length])
        outcome = relationship[length]
        
        try:    
            
            support = get_support(df, list(relationship))
        
            if support < min_sup: 
              continue
            
            row = {}

            for i in range(0,length): row["Predictor_%s" % i]  = ": ".join(predictor[i]) 

            row["Outcome"] = ": ".join(list(outcome)) 
            row["Support"] = support
            row["Confidence"] = get_confidence(df, predictor, [outcome])
            row["Lift"] = get_lift(df, predictor + [outcome])
            rows += [row]
            
        except:
            pass

# %%
table = pd.DataFrame(rows, columns=["Predictor_" + str(i) for i in range(0,length)] + ["Outcome","Support","Confidence","Lift"])
table
# Out:
#                          Predictor_0              Predictor_1         Outcome  \
# 0                     Gender: Female   Country: United States  treatment: Yes
# 1                     Gender: Female   Country: United States   treatment: No
# 2                       Gender: Male   Country: United States  treatment: Yes
# 3                       Gender: Male   Country: United States   treatment: No
# 4                       Gender: Male  Country: United Kingdom  treatment: Yes
# ...                              ...                      ...             ...
# 2228  mental_vs_physical: Don't know      obs_consequence: No  treatment: Yes
# 2229  mental_vs_physical: Don't know      obs_consequence: No   treatment: No
# 2230          mental_vs_physical: No      obs_consequence: No  treatment: Yes
# 2231          mental_vs_physical: No      obs_consequence: No   treatment: No
# 2232          mental_vs_physical: No     obs_consequence: Yes  treatment: Yes
#
#        Support  Confidence      Lift
# 0     0.102073    0.711111  1.721087
# 1     0.041467    0.288889  0.712702
# 2     0.218501    0.489286  0.921050
# 3     0.228070    0.510714  0.979966
# 4     0.057416    0.470588  0.983896
# ...        ...         ...       ...
# 2228  0.183413    0.439771  0.928565
# 2229  0.233652    0.560229  1.205770
# 2230  0.097289    0.525862  0.836449
# 2231  0.087719    0.474138  0.768749
# 2232  0.062201    0.735849  3.149908
#
# [2233 rows x 6 columns]

# %%
set_option('display.max_rows', 500)

idx = (table.Outcome == 'treatment: Yes') & (table.Confidence > 0.5) & (table.Lift > 1)
table[idx].round(2).sort_values("Confidence", ascending=False).head(10)
# Out:
#                 Predictor_0                  Predictor_1         Outcome  \
# 685   work_interfere: Often               anonymity: Yes  treatment: Yes
# 641   work_interfere: Often                benefits: Yes  treatment: Yes
# 654   work_interfere: Often            care_options: Yes  treatment: Yes
# 624   work_interfere: Often             remote_work: Yes  treatment: Yes
# 449     family_history: Yes        work_interfere: Often  treatment: Yes
# 182  Country: United States        work_interfere: Often  treatment: Yes
# 19           Gender: Female       work_interfere: Rarely  treatment: Yes
# 450     family_history: Yes       work_interfere: Rarely  treatment: Yes
# 769   work_interfere: Often       mental_vs_physical: No  treatment: Yes
# 747   work_interfere: Often  mental_health_interview: No  treatment: Yes
#
#      Support  Confidence  Lift
# 685     0.04        0.96  2.07
# 641     0.04        0.95  1.97
# 654     0.05        0.95  2.32
# 624     0.04        0.92  2.13
# 449     0.06        0.90  2.52
# 182     0.06        0.90  1.70
# 19      0.03        0.89  2.27
# 450     0.06        0.89  2.11
# 769     0.04        0.88  2.29
# 747     0.08        0.87  1.70
